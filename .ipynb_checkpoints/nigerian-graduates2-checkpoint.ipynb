# %%
# This is an EDA (Exploratory Data Analysis) on a datasets from Stutern.ng on 
# Nigerian graduates.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %matplotlib inline

# %%
#read data
data = pd.read_csv('nigerian-graduates.csv')

# %%
#show first 5 rows
data.head()
# Out:
#             Timestamp What is your gender  Year of graduation  \
# 0    2/8/2018 9:05:23                Male                2013
# 1  2/15/2018 12:11:32                Male                2014
# 2  2/15/2018 13:47:10              Female                2013
# 3  2/16/2018 13:01:34                Male                2017
# 4  2/16/2018 13:18:03              Female                2013
#
#                              Title of course studied  \
# 0                Electrical & Electronic Engineering
# 1                                         Psychology
# 2                                          Economics
# 3  Mass Communication (Communication and Language...
# 4                                         Statistics
#
#         Polytechnic/University attended  \
# 0    Obafemi Awolowo University,Ile-Ife
# 1    Obafemi Awolowo University,Ile-Ife
# 2  Bells University of Technology, Otta
# 3                 Bowen University, Iwo
# 4                Ekiti State University
#
#   What is your highest level of education?  \
# 0                        Bachelor's degree
# 1                        Bachelor's degree
# 2                        Bachelor's degree
# 3                          Master's degree
# 4                        Bachelor's degree
#
#   What best describes your current status?  \
# 0      Working full time (paid employment)
# 1      Working full time (paid employment)
# 2      Working full time (paid employment)
# 3     Self-employed/freelance/entrepreneur
# 4      Working full time (paid employment)
#
#    How many jobs have you had since graduation including your current one?  \
# 0                                                  3
# 1                                                  2
# 2                                                  2
# 3                                                  0
# 4                                                  3
#
#   Have you completed your NYSC?  \
# 0                           NaN
# 1                           Yes
# 2                           Yes
# 3                           Yes
# 4                           Yes
#
#    If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?  \
# 0                                                NaN
# 1                                             2017.0
# 2                                                NaN
# 3                                                NaN
# 4                                             2016.0
#
#                                      ...                                      \
# 0                                    ...
# 1                                    ...
# 2                                    ...
# 3                                    ...
# 4                                    ...
#
#   What currency are you currently paid in?  \
# 0                                    Naira
# 1                                    Naira
# 2                                    Naira
# 3                                      NaN
# 4                                    Naira
#
#   Approximately how many hours a day do you currently work?  \
# 0                                                8.0
# 1                                                8.0
# 2                                               14.0
# 3                                                NaN
# 4                                                8.0
#
#   As far as you are aware, what was most important to your current employer about your qualification?  \
# 0                         No one thing was important
# 1  IT/SIWES/Internship experience (gained as part...
# 2                           The subject(s) I studied
# 3                                                NaN
# 4  IT/SIWES/Internship experience (gained as part...
#
#             How do you find out about your job(s)?  \
# 0                                       Internship
# 1                                       Internship
# 2                               Employer's website
# 3                                              NaN
# 4  Personal contacts, including family and friends
#
#   Thinking about your current employment, did you work for your employer before or during your  higher education study?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                NaN
# 4                                                 No
#
#   Which form of transport do you use the most?  \
# 0                                          Bus
# 1                                          BRT
# 2                    Uber/Taxify/Taxi services
# 3                                          NaN
# 4                          Commercial Vehicles
#
#   Were you able to rent an apartment or buy a car from the salary you got from your first job?  \
# 0                             Yes: From my first job
# 1                            No: From my current job
# 2                            No: From my current job
# 3                                                NaN
# 4                                                 No
#
#   My course of study prepared me well for employment  \
# 0                                                 No
# 1                                  Strongly Disagree
# 2                                           Disagree
# 3                                                NaN
# 4                                              Agree
#
#   My course of study prepared me well for further studies  \
# 0                                                 No
# 1                                              Agree
# 2                                              Agree
# 3                                                NaN
# 4                                              Agree
#
#   Which of these skills/knowledge did your higher education prepare you for?
# 0  Critical thinking skills, Ability to solve com...
# 1  Critical thinking skills, Ability to solve com...
# 2  Ability to work with others, Written communica...
# 3                                                NaN
# 4                           Critical thinking skills
#
# [5 rows x 36 columns]

# %%
data.describe() #would only describe continuous variables
# Out:
#        Year of graduation  \
# count         5219.000000
# mean          2015.329182
# std              1.305153
# min           2013.000000
# 25%           2014.000000
# 50%           2015.000000
# 75%           2016.000000
# max           2017.000000
#
#        How many jobs have you had since graduation including your current one?  \
# count                                        5219.000000
# mean                                            1.136999
# std                                             1.140146
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                            10.000000
#
#        If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?  \
# count                                        4278.000000
# mean                                         2016.579009
# std                                             1.354837
# min                                          2013.000000
# 25%                                          2016.000000
# 50%                                          2017.000000
# 75%                                          2017.000000
# max                                          2019.000000
#
#        Approximately how many hours a day do you currently work?
# count                                        3432.000000
# mean                                            8.983683
# std                                             2.636293
# min                                             0.000000
# 25%                                             8.000000
# 50%                                             9.000000
# 75%                                            10.000000
# max                                            24.000000

# %%
#rows and columns
data.shape
# Out:
# (5219, 36)

# %%
#let's take a look at the columns
data.columns
# Out:
# Index(['Timestamp', 'What is your gender', 'Year of graduation',
#        'Title of course studied', 'Polytechnic/University attended',
#        'What is your highest level of education?',
#        'What best describes your current status?',
#        'How many jobs have you had since graduation including your current one?',
#        'Have you completed your NYSC?',
#        'If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?',
#        'Did you get your first full time job through your NYSC placement?',
#        'Thinking about your first employment after graduation, what was your job level?',
#        'What is/was your job role?',
#        'What sector/industry is your company in? (E.g. Banking, Agriculture, Telecommunication)',
#        'Still thinking about your first employment, what is/was your monthly income level?',
#        'Did you need your higher education qualification to get your first job (the actual qualification, not the subject of study)?',
#        'What was the most significant reason for deciding to take your first job?',
#        'Thinking about your current employment, what is your job level?',
#        'What is your job role?',
#        'What sector/industry is your company in? (E.g. Banking, Agriculture, Telecommunication).1',
#        'What is your current monthly income level?',
#        'Did you need your higher education qualification to get this job (the actual qualification, not the subject of study)?',
#        'What was the most significant reason for deciding to take this job?',
#        'Which employer in the country do you think offers the best opportunities for graduates?',
#        'Reason why?', 'Which sector is your most preferred sector to work in?',
#        'What currency are you currently paid in?',
#        'Approximately how many hours a day do you currently work?',
#        'As far as you are aware, what was most important to your current employer about your qualification?',
#        'How do you find out about your job(s)?',
#        'Thinking about your current employment, did you work for your employer before or during your  higher education study?',
#        'Which form of transport do you use the most?',
#        'Were you able to rent an apartment or buy a car from the salary you got from your first job?',
#        'My course of study prepared me well for employment',
#        'My course of study prepared me well for further studies',
#        'Which of these skills/knowledge did your higher education prepare you for?'],
#       dtype='object')

# %%
#column names are too long. let's rename columns
#create new columns
new_columns = ['created_at', 'gender', 'graduated', 'course', 'school', 'education_level', 'current_status',
              'jobs_after_graduation_plus_current', 'completed_nysc', 'completed_nysc_year', 'first_job_through_nysc',
              'first_job_level', 'first_job_role', 'first_job_company_sector', 'first_monthly_income', 'needed_qualification_for_first_job',
              'first_job_reason', 'current_job_level', 'current_job_role', 'current_company_sector', 'current_monthly_income',
              'needed_qualification_for_current_job', 'current_job_reason', 'best_company_for_graduates',
              'why_company_best_for_graduates', 'best_sector_to_work', 'currency_paid_with', 'hours_worked_per_day',
              'most_important_to_current_employer', 'job_source', 'worked_for_current_employer_during_school',
              'transport_form_used', 'get_car_or_apartment_from_first_job', 'studied_course_prepared_employment',
              'studied_course_prepared_further_studies', 'skills_school_prepared_gradutae']

# %%
#rename columns 
data.columns = new_columns

# %%
#drop created_at column 
data.drop('created_at', axis=1, inplace=True)

# %%
#check if the rows count are same across all columns
data.count() 
#some columns are missing values
# Out:
# gender                                       5219
# graduated                                    5219
# course                                       5219
# school                                       5219
# education_level                              5219
# current_status                               5219
# jobs_after_graduation_plus_current           5219
# completed_nysc                               5218
# completed_nysc_year                          4278
# first_job_through_nysc                       5218
# first_job_level                              1656
# first_job_role                               1654
# first_job_company_sector                     1656
# first_monthly_income                         1656
# needed_qualification_for_first_job           1656
# first_job_reason                             1656
# current_job_level                            3432
# current_job_role                             3431
# current_company_sector                       3432
# current_monthly_income                       3432
# needed_qualification_for_current_job         3431
# current_job_reason                           3432
# best_company_for_graduates                   2958
# why_company_best_for_graduates               3109
# best_sector_to_work                          3297
# currency_paid_with                           3432
# hours_worked_per_day                         3432
# most_important_to_current_employer           3432
# job_source                                   3432
# worked_for_current_employer_during_school    3432
# transport_form_used                          3432
# get_car_or_apartment_from_first_job          3432
# studied_course_prepared_employment           3432
# studied_course_prepared_further_studies      3432
# skills_school_prepared_gradutae              3432
# dtype: int64

# %%
#check columns with mising values
null_columns = data.columns[data.isnull().any()]
null_columns
# Out:
# Index(['completed_nysc', 'completed_nysc_year', 'first_job_through_nysc',
#        'first_job_level', 'first_job_role', 'first_job_company_sector',
#        'first_monthly_income', 'needed_qualification_for_first_job',
#        'first_job_reason', 'current_job_level', 'current_job_role',
#        'current_company_sector', 'current_monthly_income',
#        'needed_qualification_for_current_job', 'current_job_reason',
#        'best_company_for_graduates', 'why_company_best_for_graduates',
#        'best_sector_to_work', 'currency_paid_with', 'hours_worked_per_day',
#        'most_important_to_current_employer', 'job_source',
#        'worked_for_current_employer_during_school', 'transport_form_used',
#        'get_car_or_apartment_from_first_job',
#        'studied_course_prepared_employment',
#        'studied_course_prepared_further_studies',
#        'skills_school_prepared_gradutae'],
#       dtype='object')

# %%
#do a count of the null values on these columns
data[null_columns].isnull().sum()
#we have got a lot of null values on our hands
# Out:
# completed_nysc                                  1
# completed_nysc_year                           941
# first_job_through_nysc                          1
# first_job_level                              3563
# first_job_role                               3565
# first_job_company_sector                     3563
# first_monthly_income                         3563
# needed_qualification_for_first_job           3563
# first_job_reason                             3563
# current_job_level                            1787
# current_job_role                             1788
# current_company_sector                       1787
# current_monthly_income                       1787
# needed_qualification_for_current_job         1788
# current_job_reason                           1787
# best_company_for_graduates                   2261
# why_company_best_for_graduates               2110
# best_sector_to_work                          1922
# currency_paid_with                           1787
# hours_worked_per_day                         1787
# most_important_to_current_employer           1787
# job_source                                   1787
# worked_for_current_employer_during_school    1787
# transport_form_used                          1787
# get_car_or_apartment_from_first_job          1787
# studied_course_prepared_employment           1787
# studied_course_prepared_further_studies      1787
# skills_school_prepared_gradutae              1787
# dtype: int64

# %%
#lets look at these columns individually

# %%
#drop rows where completed_nysc is missing since its just one row
data.dropna(subset=['completed_nysc'], inplace=True)

# %%
#let's columns with missing values
null_columns = data.columns[data.isnull().any()]
data[null_columns].isnull().sum()
# Out:
# completed_nysc_year                           940
# first_job_level                              3563
# first_job_role                               3564
# first_job_company_sector                     3563
# first_monthly_income                         3563
# needed_qualification_for_first_job           3563
# first_job_reason                             3563
# current_job_level                            1787
# current_job_role                             1787
# current_company_sector                       1787
# current_monthly_income                       1787
# needed_qualification_for_current_job         1787
# current_job_reason                           1787
# best_company_for_graduates                   2261
# why_company_best_for_graduates               2109
# best_sector_to_work                          1922
# currency_paid_with                           1787
# hours_worked_per_day                         1787
# most_important_to_current_employer           1787
# job_source                                   1787
# worked_for_current_employer_during_school    1787
# transport_form_used                          1787
# get_car_or_apartment_from_first_job          1787
# studied_course_prepared_employment           1787
# studied_course_prepared_further_studies      1787
# skills_school_prepared_gradutae              1787
# dtype: int64

# %%
#lets take a look at the completed_nysc_year column
data['completed_nysc_year'].value_counts(dropna=False)
# Out:
#  2017.0    1513
# NaN         940
#  2018.0     832
#  2016.0     790
#  2015.0     541
#  2014.0     303
#  2019.0     224
#  2013.0      75
# Name: completed_nysc_year, dtype: int64

# %%
#lets look at the completed_nysc column
data['completed_nysc'].value_counts(dropna=False)
# Out:
# Yes        3418
# No         1023
# Ongoing     777
# Name: completed_nysc, dtype: int64

# %%
#The 'completed nysc' ought be to either 'yes' or 'no'. Its either you have completed or not completed
#NYSC. Firstly, we gonna replace 'Ongoing' with 'No'

# %%
#Replace 'Ongoing' with 'No'
def replaceOngoingWithNo(data):
    for i in data.index:
        if data.at[i, 'completed_nysc'] == 'Ongoing':
            data.at[i, 'completed_nysc'] = 'No'
            
replaceOngoingWithNo(data)

# %%
#Just to confirm
data['completed_nysc'].value_counts(dropna=False)
# Out:
# Yes    3418
# No     1800
# Name: completed_nysc, dtype: int64

# %%
#I am gonna assume that null values on 'completed_nysc_year' is perhaps, due to some graduates yet
#to finish their NYSC. I am gonna replace 'completed_nysc_year' null values with 0 where 'completed_nysc' is no

# %%
def replaceNyscYear(data) :
    for i in data.index:
        cn = data.at[i, 'completed_nysc']
        if cn == 'No':
            data.at[i, 'completed_nysc_year'] = 0
            
replaceNyscYear(data)

# %%
#lets see if 'completed_nysc_year' still has missing values
data['completed_nysc_year'].value_counts(dropna=False)
# Out:
#  0.0       1800
#  2017.0    1481
#  2016.0     768
#  2015.0     515
#  2014.0     285
# NaN         167
#  2018.0     126
#  2013.0      73
#  2019.0       3
# Name: completed_nysc_year, dtype: int64

# %%
#We have about 167 rows with missing values on the this column. 
#Let's see if there are instance were 'completed_nysc' equals yes and 'completed_nysc_year' is null. If there is 
#then it is wrong, we gonna have to predict 'completed_nysc_year' based on the year the person graduated.
#we gonna add a year to the year graduated. NYSC lasts for a year and in most cases, done immediately
#after graduation

# %%
data.loc[(data['completed_nysc_year'].isnull()) & (data['completed_nysc'] == 'Yes')]
# Out:
#                  gender  graduated  \
# 2                Female       2013
# 3                  Male       2017
# 74                 Male       2013
# 102                Male       2013
# 111              Female       2016
# 117                Male       2016
# 127   Prefer not to say       2013
# 128              Female       2013
# 133                Male       2014
# 144                Male       2013
# 149                Male       2013
# 158              Female       2013
# 226              Female       2016
# 275              Female       2015
# 291              Female       2015
# 339                Male       2014
# 388              Female       2014
# 511                Male       2015
# 543                Male       2014
# 648              Female       2016
# 693                Male       2014
# 728              Female       2015
# 808                Male       2015
# 811              Female       2015
# 823                Male       2014
# 834              Female       2015
# 836              Female       2016
# 851                Male       2015
# 859                Male       2013
# 946              Female       2014
# ...                 ...        ...
# 4144               Male       2015
# 4149             Female       2013
# 4156             Female       2016
# 4188               Male       2015
# 4243             Female       2014
# 4250             Female       2016
# 4269               Male       2013
# 4275               Male       2016
# 4282               Male       2014
# 4312             Female       2015
# 4329               Male       2014
# 4337               Male       2016
# 4359               Male       2013
# 4400             Female       2016
# 4421             Female       2015
# 4469               Male       2015
# 4497               Male       2014
# 4517               Male       2015
# 4531               Male       2014
# 4568             Female       2015
# 4585             Female       2017
# 4589             Female       2015
# 4610               Male       2017
# 4634               Male       2013
# 4648             Female       2015
# 4659             Female       2014
# 4744               Male       2013
# 4781               Male       2017
# 4790               Male       2015
# 4829             Female       2013
#
#                                                  course  \
# 2                                             Economics
# 3     Mass Communication (Communication and Language...
# 74    Mass Communication (Communication and Language...
# 102                                    Computer Science
# 111                               Education And Biology
# 117                               Physics and Astronomy
# 127                                        Architecture
# 128                                        Microbiology
# 133                              Mechanical Engineering
# 144                                           Marketing
# 149                 Electrical & Electronic Engineering
# 158                   History and International Studies
# 226                                Computer Engineering
# 275                                         Accountancy
# 291                   History and International Studies
# 339                              Agricultural Economics
# 388                                          Statistics
# 511   Mass Communication (Communication and Language...
# 543                                        Biochemistry
# 648                   History and International Studies
# 693                                    Computer Science
# 728                                 Business Management
# 808                                   Civil Engineering
# 811                                        Biochemistry
# 823          Public Administration and Local Government
# 834                                   Political Science
# 836                                           Economics
# 851                                        Microbiology
# 859                                        Biochemistry
# 946                                        Microbiology
# ...                                                 ...
# 4144                                Education & Physics
# 4149                                Banking and Finance
# 4156                            Business Administration
# 4188                                   Computer Science
# 4243                               Computer Engineering
# 4250                                            Geology
# 4269                    Education And Political Science
# 4275                                        Accountancy
# 4282                Electrical & Electronic Engineering
# 4312                                       Biochemistry
# 4329                             Mechanical Engineering
# 4337                                          Economics
# 4359                                           Medicine
# 4400                             Electrical Engineering
# 4421                            Business Administration
# 4469                                     Animal Science
# 4497                                          Economics
# 4517                              Education & Economics
# 4531                 Linguistics and Nigerian Languages
# 4568                       English and Literary Studies
# 4585                                         Statistics
# 4589                                       Microbiology
# 4610                                          Economics
# 4634                    Library and Information Science
# 4648                                            Zoology
# 4659         Public Administration and Local Government
# 4744                                   Computer Science
# 4781                                       Biochemistry
# 4790      Industrial Relations and Personnel Management
# 4829              Home Science, Nutrition and Dietetics
#
#                                                  school  \
# 2                  Bells University of Technology, Otta
# 3                                 Bowen University, Iwo
# 74                                  University of Lagos
# 102                                   University of Uyo
# 111                                 University of Lagos
# 117                  Obafemi Awolowo University,Ile-Ife
# 127           Abubakar Tafawa Balewa University, Bauchi
# 128                               University of Calabar
# 133          The Polytechnic Ibadan, Ibadab, Oyo State.
# 144                     Nnamdi Azikiwe University, Awka
# 149            Federal University of Technology, Owerri
# 158                  Lagos State University Ojo, Lagos.
# 226               Olabisi Onabanjo University Ago-Iwoye
# 275                               Bowen University, Iwo
# 291                                University of Ilorin
# 339                                 University of Benin
# 388                                University of Ilorin
# 511               Olabisi Onabanjo University Ago-Iwoye
# 543              Michael Okpara Uni. of Agric., Umudike
# 648                         Redeemer's University, Mowe
# 693   Abdu Gusau Polytechnic, Talata Mafara, Zamfara...
# 728                       University of Nigeria, Nsukka
# 808                University of Agriculture, Abeokuta.
# 811             Federal University of Technology, Akure
# 823                             University of Maiduguri
# 834                       Delta State University Abraka
# 836                                 University of Lagos
# 851   Ogun State Institute of Technology, Igbesa Oba...
# 859                     Nnamdi Azikiwe University, Awka
# 946                  Obafemi Awolowo University,Ile-Ife
# ...                                                 ...
# 4144                                University of Benin
# 4149                                University of Lagos
# 4156  Lagos State Polytechnic, Ikorodu, Ikeja, Lagos...
# 4188            Federal University of Technology, Akure
# 4243  Lagos State Polytechnic, Ikorodu, Ikeja, Lagos...
# 4250                    Nnamdi Azikiwe University, Awka
# 4269                       Imo State University, Owerri
# 4275              Olabisi Onabanjo University Ago-Iwoye
# 4282                               University of Ilorin
# 4312                      University of Nigeria, Nsukka
# 4329                        University of Port-Harcourt
# 4337                   Taraba State University, Jalingo
# 4359                     Ahmadu Bello University, Zaria
# 4400                            Covenant University Ota
# 4421                      Gombe State Univeristy, Gombe
# 4469  Ladoke Akintola University of Technology, Ogbo...
# 4497                               University of Ilorin
# 4517                               University of Ilorin
# 4531                               University of Ilorin
# 4568                               University of Ibadan
# 4585     Yaba College of Technology, Yaba, Lagos State.
# 4589                       Imo State University, Owerri
# 4610               University of Agriculture, Abeokuta.
# 4634                               University of Ibadan
# 4648             Michael Okpara Uni. of Agric., Umudike
# 4659                          Caritas University, Enugu
# 4744                      Kogi State University Anyigba
# 4781  Ladoke Akintola University of Technology, Ogbo...
# 4790          Tai Solarin Univ. of Education, Ijebu-Ode
# 4829                      University of Nigeria, Nsukka
#
#                     education_level  \
# 2                 Bachelor's degree
# 3                   Master's degree
# 74                  Master's degree
# 102                 Master's degree
# 111               Bachelor's degree
# 117               Bachelor's degree
# 127               Bachelor's degree
# 128               Bachelor's degree
# 133   Higher National Diploma (HND)
# 144               Bachelor's degree
# 149               Bachelor's degree
# 158               Bachelor's degree
# 226               Bachelor's degree
# 275               Bachelor's degree
# 291               Bachelor's degree
# 339               Bachelor's degree
# 388               Bachelor's degree
# 511               Bachelor's degree
# 543               Bachelor's degree
# 648               Bachelor's degree
# 693               Bachelor's degree
# 728                      MBA degree
# 808               Bachelor's degree
# 811               Bachelor's degree
# 823               Bachelor's degree
# 834               Bachelor's degree
# 836               Bachelor's degree
# 851   Higher National Diploma (HND)
# 859               Bachelor's degree
# 946               Bachelor's degree
# ...                             ...
# 4144              Bachelor's degree
# 4149                     MBA degree
# 4156  Higher National Diploma (HND)
# 4188              Bachelor's degree
# 4243  Higher National Diploma (HND)
# 4250              Bachelor's degree
# 4269              Bachelor's degree
# 4275              Bachelor's degree
# 4282              Bachelor's degree
# 4312              Bachelor's degree
# 4329              Bachelor's degree
# 4337              Bachelor's degree
# 4359              Bachelor's degree
# 4400              Bachelor's degree
# 4421              Bachelor's degree
# 4469                Master's degree
# 4497                Master's degree
# 4517              Bachelor's degree
# 4531              Bachelor's degree
# 4568              Bachelor's degree
# 4585  Higher National Diploma (HND)
# 4589              Bachelor's degree
# 4610              Bachelor's degree
# 4634  Higher National Diploma (HND)
# 4648              Bachelor's degree
# 4659              Bachelor's degree
# 4744              Bachelor's degree
# 4781              Bachelor's degree
# 4790              Bachelor's degree
# 4829              Bachelor's degree
#
#                                          current_status  \
# 2                   Working full time (paid employment)
# 3                  Self-employed/freelance/entrepreneur
# 74                  Working full time (paid employment)
# 102                Self-employed/freelance/entrepreneur
# 111                                          Unemployed
# 117                 Working full time (paid employment)
# 127                Self-employed/freelance/entrepreneur
# 128                 Working full time (paid employment)
# 133                                          Unemployed
# 144                                          Unemployed
# 149                                          Unemployed
# 158                Self-employed/freelance/entrepreneur
# 226                                          Unemployed
# 275                                          Unemployed
# 291   Engaged in part-time further study, training o...
# 339   Due to start a job in the next month/developin...
# 388                Self-employed/freelance/entrepreneur
# 511   Doing something else (e.g. looking after home ...
# 543   Voluntary or other unpaid work or on an intern...
# 648                                          Unemployed
# 693                 Working full time (paid employment)
# 728                 Working full time (paid employment)
# 808                 Working full time (paid employment)
# 811                                          Unemployed
# 823                 Working full time (paid employment)
# 834                Self-employed/freelance/entrepreneur
# 836                 Working full time (paid employment)
# 851                Self-employed/freelance/entrepreneur
# 859                 Working full time (paid employment)
# 946                 Working full time (paid employment)
# ...                                                 ...
# 4144                                         Unemployed
# 4149                Working full time (paid employment)
# 4156                Working full time (paid employment)
# 4188               Self-employed/freelance/entrepreneur
# 4243                                         Unemployed
# 4250                                         Unemployed
# 4269                Working full time (paid employment)
# 4275  Due to start a job in the next month/developin...
# 4282  Due to start a job in the next month/developin...
# 4312  Voluntary or other unpaid work or on an intern...
# 4329  Engaged in part-time further study, training o...
# 4337                                         Unemployed
# 4359                Working full time (paid employment)
# 4400                                         Unemployed
# 4421               Self-employed/freelance/entrepreneur
# 4469                                         Unemployed
# 4497                                         Unemployed
# 4517                Working full time (paid employment)
# 4531  Voluntary or other unpaid work or on an intern...
# 4568                                         Unemployed
# 4585  Voluntary or other unpaid work or on an intern...
# 4589                Working full time (paid employment)
# 4610                                         Unemployed
# 4634                Working full time (paid employment)
# 4648                                         Unemployed
# 4659                                         Unemployed
# 4744               Self-employed/freelance/entrepreneur
# 4781                                         Unemployed
# 4790                                         Unemployed
# 4829  Doing something else (e.g. looking after home ...
#
#       jobs_after_graduation_plus_current completed_nysc  completed_nysc_year  \
# 2                                      2            Yes                  NaN
# 3                                      0            Yes                  NaN
# 74                                     2            Yes                  NaN
# 102                                    3            Yes                  NaN
# 111                                    0            Yes                  NaN
# 117                                    2            Yes                  NaN
# 127                                    2            Yes                  NaN
# 128                                    1            Yes                  NaN
# 133                                    0            Yes                  NaN
# 144                                    2            Yes                  NaN
# 149                                    0            Yes                  NaN
# 158                                    1            Yes                  NaN
# 226                                    1            Yes                  NaN
# 275                                    2            Yes                  NaN
# 291                                    0            Yes                  NaN
# 339                                    2            Yes                  NaN
# 388                                    0            Yes                  NaN
# 511                                    0            Yes                  NaN
# 543                                    0            Yes                  NaN
# 648                                    0            Yes                  NaN
# 693                                    2            Yes                  NaN
# 728                                    3            Yes                  NaN
# 808                                    3            Yes                  NaN
# 811                                    0            Yes                  NaN
# 823                                    2            Yes                  NaN
# 834                                    1            Yes                  NaN
# 836                                    1            Yes                  NaN
# 851                                    4            Yes                  NaN
# 859                                    4            Yes                  NaN
# 946                                    3            Yes                  NaN
# ...                                  ...            ...                  ...
# 4144                                   0            Yes                  NaN
# 4149                                   3            Yes                  NaN
# 4156                                   1            Yes                  NaN
# 4188                                   1            Yes                  NaN
# 4243                                   1            Yes                  NaN
# 4250                                   0            Yes                  NaN
# 4269                                   1            Yes                  NaN
# 4275                                   0            Yes                  NaN
# 4282                                   1            Yes                  NaN
# 4312                                   2            Yes                  NaN
# 4329                                   0            Yes                  NaN
# 4337                                   1            Yes                  NaN
# 4359                                   3            Yes                  NaN
# 4400                                   0            Yes                  NaN
# 4421                                   1            Yes                  NaN
# 4469                                   0            Yes                  NaN
# 4497                                   0            Yes                  NaN
# 4517                                   2            Yes                  NaN
# 4531                                   2            Yes                  NaN
# 4568                                   0            Yes                  NaN
# 4585                                   1            Yes                  NaN
# 4589                                   2            Yes                  NaN
# 4610                                   0            Yes                  NaN
# 4634                                   1            Yes                  NaN
# 4648                                   0            Yes                  NaN
# 4659                                   0            Yes                  NaN
# 4744                                   3            Yes                  NaN
# 4781                                   0            Yes                  NaN
# 4790                                   0            Yes                  NaN
# 4829                                   0            Yes                  NaN
#
#      first_job_through_nysc  \
# 2                        No
# 3                        No
# 74                       No
# 102                      No
# 111                     Yes
# 117                      No
# 127                      No
# 128                      No
# 133                      No
# 144                      No
# 149                      No
# 158                      No
# 226                      No
# 275                     Yes
# 291                      No
# 339                      No
# 388                      No
# 511                      No
# 543                     Yes
# 648                      No
# 693                      No
# 728                      No
# 808                      No
# 811                     Yes
# 823                      No
# 834                      No
# 836                      No
# 851                      No
# 859                     Yes
# 946                      No
# ...                     ...
# 4144                     No
# 4149                     No
# 4156                     No
# 4188                     No
# 4243                     No
# 4250                     No
# 4269                    Yes
# 4275                     No
# 4282                     No
# 4312                     No
# 4329                     No
# 4337                     No
# 4359                     No
# 4400                     No
# 4421                     No
# 4469                    Yes
# 4497                     No
# 4517                     No
# 4531                     No
# 4568                    Yes
# 4585                     No
# 4589                     No
# 4610                     No
# 4634                     No
# 4648                     No
# 4659                     No
# 4744                     No
# 4781                     No
# 4790                     No
# 4829                     No
#
#                             ...                         currency_paid_with  \
# 2                           ...                                      Naira
# 3                           ...                                        NaN
# 74                          ...                                      Naira
# 102                         ...                                      Naira
# 111                         ...                                        NaN
# 117                         ...                                      Naira
# 127                         ...                                      Naira
# 128                         ...                                      Naira
# 133                         ...                                        NaN
# 144                         ...                                      Naira
# 149                         ...                                        NaN
# 158                         ...                                      Naira
# 226                         ...                                      Naira
# 275                         ...                                      Naira
# 291                         ...                                        NaN
# 339                         ...                                      Naira
# 388                         ...                                        NaN
# 511                         ...                                        NaN
# 543                         ...                                        NaN
# 648                         ...                                        NaN
# 693                         ...                                      Naira
# 728                         ...                                      Naira
# 808                         ...                                      Naira
# 811                         ...                                        NaN
# 823                         ...                                      Naira
# 834                         ...                                      Naira
# 836                         ...                                      Naira
# 851                         ...                                      Naira
# 859                         ...                                      Naira
# 946                         ...                                      Naira
# ...                         ...                                        ...
# 4144                        ...                                        NaN
# 4149                        ...                                      Naira
# 4156                        ...                                      Naira
# 4188                        ...                                      Naira
# 4243                        ...                                      Naira
# 4250                        ...                                        NaN
# 4269                        ...                                      Naira
# 4275                        ...                                        NaN
# 4282                        ...                                      Naira
# 4312                        ...                                      Naira
# 4329                        ...                                        NaN
# 4337                        ...                                      Naira
# 4359                        ...                                      Naira
# 4400                        ...                                        NaN
# 4421                        ...                                      Naira
# 4469                        ...                                        NaN
# 4497                        ...                                        NaN
# 4517                        ...                                      Naira
# 4531                        ...                                      Naira
# 4568                        ...                                        NaN
# 4585                        ...                                      Naira
# 4589                        ...                                      Naira
# 4610                        ...                                        NaN
# 4634                        ...                                      Naira
# 4648                        ...                                        NaN
# 4659                        ...                                        NaN
# 4744                        ...                                      Naira
# 4781                        ...                                        NaN
# 4790                        ...                                        NaN
# 4829                        ...                                        NaN
#
#      hours_worked_per_day                 most_important_to_current_employer  \
# 2                    14.0                           The subject(s) I studied
# 3                     NaN                                                NaN
# 74                   10.0                                 The level of study
# 102                   8.0  IT/SIWES/Internship experience (gained as part...
# 111                   NaN                                                NaN
# 117                   8.0       My Previous work experience and achievements
# 127                   8.0  IT/SIWES/Internship experience (gained as part...
# 128                   9.0                                         Don't know
# 133                   NaN                                                NaN
# 144                  12.0                           The subject(s) I studied
# 149                   NaN                                                NaN
# 158                  12.0                         No one thing was important
# 226                  10.0  IT/SIWES/Internship experience (gained as part...
# 275                   9.0                                 The level of study
# 291                   NaN                                                NaN
# 339                   8.0                                         Don't know
# 388                   NaN                                                NaN
# 511                   NaN                                                NaN
# 543                   NaN                                                NaN
# 648                   NaN                                                NaN
# 693                   9.0                                 The level of study
# 728                  10.0                                 The level of study
# 808                   9.0    Past job experiences and willingness to learn.
# 811                   NaN                                                NaN
# 823                  13.0                                         Don't know
# 834                   4.0                         No one thing was important
# 836                   8.0                                 The level of study
# 851                   8.0  IT/SIWES/Internship experience (gained as part...
# 859                   8.0                                         Don't know
# 946                   8.0            Volunteer Experience gained during NYSC
# ...                   ...                                                ...
# 4144                  NaN                                                NaN
# 4149                  9.0                                   Ability to adapt
# 4156                  8.0                                         Don't know
# 4188                 10.0  IT/SIWES/Internship experience (gained as part...
# 4243                  9.0                                         Don't know
# 4250                  NaN                                                NaN
# 4269                  9.0                           The subject(s) I studied
# 4275                  NaN                                                NaN
# 4282                 10.0  IT/SIWES/Internship experience (gained as part...
# 4312                  7.0                                 The level of study
# 4329                  NaN                                                NaN
# 4337                  9.0  IT/SIWES/Internship experience (gained as part...
# 4359                  9.0                           The subject(s) I studied
# 4400                  NaN                                                NaN
# 4421                  9.0                           The subject(s) I studied
# 4469                  NaN                                                NaN
# 4497                  NaN                                                NaN
# 4517                  8.0            Level of commitment,  sharing of ideas.
# 4531                  9.0                           The subject(s) I studied
# 4568                  NaN                                                NaN
# 4585                  8.0                           The subject(s) I studied
# 4589                  9.0                                 The level of study
# 4610                  NaN                                                NaN
# 4634                 10.0                           The subject(s) I studied
# 4648                  NaN                                                NaN
# 4659                  NaN                                                NaN
# 4744                  8.0                                           Skillset
# 4781                  NaN                                                NaN
# 4790                  NaN                                                NaN
# 4829                  NaN                                                NaN
#
#                                            job_source  \
# 2                                  Employer's website
# 3                                                 NaN
# 74    Personal contacts, including family and friends
# 102     Media (e.g. newspaper/magazine advertisement)
# 111                                               NaN
# 117        Social media/professional networking sites
# 127     Media (e.g. newspaper/magazine advertisement)
# 128                                Employer's website
# 133                                               NaN
# 144     Media (e.g. newspaper/magazine advertisement)
# 149                                               NaN
# 158                Recruitment agency/Online job site
# 226                Recruitment agency/Online job site
# 275        Social media/professional networking sites
# 291                                               NaN
# 339     Media (e.g. newspaper/magazine advertisement)
# 388                                               NaN
# 511                                               NaN
# 543                                               NaN
# 648                                               NaN
# 693   Personal contacts, including family and friends
# 728   Personal contacts, including family and friends
# 808                                        Internship
# 811                                               NaN
# 823   Personal contacts, including family and friends
# 834   Personal contacts, including family and friends
# 836   Personal contacts, including family and friends
# 851        Social media/professional networking sites
# 859   Personal contacts, including family and friends
# 946   Personal contacts, including family and friends
# ...                                               ...
# 4144                                              NaN
# 4149  Personal contacts, including family and friends
# 4156  Personal contacts, including family and friends
# 4188                                       Internship
# 4243  Personal contacts, including family and friends
# 4250                                              NaN
# 4269  Personal contacts, including family and friends
# 4275                                              NaN
# 4282               Recruitment agency/Online job site
# 4312               Recruitment agency/Online job site
# 4329                                              NaN
# 4337                                       Internship
# 4359    Media (e.g. newspaper/magazine advertisement)
# 4400                                              NaN
# 4421  Personal contacts, including family and friends
# 4469                                              NaN
# 4497                                              NaN
# 4517  Personal contacts, including family and friends
# 4531               Recruitment agency/Online job site
# 4568                                              NaN
# 4585    Media (e.g. newspaper/magazine advertisement)
# 4589  Personal contacts, including family and friends
# 4610                                              NaN
# 4634  Personal contacts, including family and friends
# 4648                                              NaN
# 4659                                              NaN
# 4744  Personal contacts, including family and friends
# 4781                                              NaN
# 4790                                              NaN
# 4829                                              NaN
#
#              worked_for_current_employer_during_school  \
# 2                                                   No
# 3                                                  NaN
# 74                                                  No
# 102              Yes: during my higher education study
# 111                                                NaN
# 117                                                 No
# 127                    Yes: before my higher education
# 128                                                 No
# 133                                                NaN
# 144                                                 No
# 149                                                NaN
# 158                                                 No
# 226                                                 No
# 275                                                 No
# 291                                                NaN
# 339                                                 No
# 388                                                NaN
# 511                                                NaN
# 543                                                NaN
# 648                                                NaN
# 693                                                 No
# 728   Yes: before and during my higher education study
# 808              Yes: during my higher education study
# 811                                                NaN
# 823                                                 No
# 834                                                 No
# 836                                                 No
# 851   Yes: before and during my higher education study
# 859                                                 No
# 946                                                 No
# ...                                                ...
# 4144                                               NaN
# 4149                                                No
# 4156                                                No
# 4188                                                No
# 4243                                                No
# 4250                                               NaN
# 4269                                                No
# 4275                                               NaN
# 4282                                                No
# 4312                                                No
# 4329                                               NaN
# 4337  Yes: before and during my higher education study
# 4359                                                No
# 4400                                               NaN
# 4421             Yes: during my higher education study
# 4469                                               NaN
# 4497                                               NaN
# 4517                                                No
# 4531                                                No
# 4568                                               NaN
# 4585                                                No
# 4589                                                No
# 4610                                               NaN
# 4634                                                No
# 4648                                               NaN
# 4659                                               NaN
# 4744                                                No
# 4781                                               NaN
# 4790                                               NaN
# 4829                                               NaN
#
#             transport_form_used get_car_or_apartment_from_first_job  \
# 2     Uber/Taxify/Taxi services             No: From my current job
# 3                           NaN                                 NaN
# 74    Keke Marwa/Napep/Tricycle             No: From my current job
# 102                         Car              Yes: From my first job
# 111                         NaN                                 NaN
# 117                         Car              Yes: From my first job
# 127         Commercial Vehicles                                  No
# 128         Commercial Vehicles                                  No
# 133                         NaN                                 NaN
# 144         Commercial Vehicles                                  No
# 149                         NaN                                 NaN
# 158         Commercial Vehicles                                  No
# 226         Commercial Vehicles                                  No
# 275         Commercial Vehicles              Yes: From my first job
# 291                         NaN                                 NaN
# 339         Commercial Vehicles                                  No
# 388                         NaN                                 NaN
# 511                         NaN                                 NaN
# 543                         NaN                                 NaN
# 648                         NaN                                 NaN
# 693   Keke Marwa/Napep/Tricycle                                  No
# 728         Commercial Vehicles                                  No
# 808         Commercial Vehicles                                  No
# 811                         NaN                                 NaN
# 823         Commercial Vehicles                                  No
# 834         Commercial Vehicles                                  No
# 836                         Car             No: From my current job
# 851         Commercial Vehicles             No: From my current job
# 859         Commercial Vehicles             No: From my current job
# 946         Commercial Vehicles                                  No
# ...                         ...                                 ...
# 4144                        NaN                                 NaN
# 4149                        BRT                                  No
# 4156                        BRT             No: From my current job
# 4188                        Car                                  No
# 4243  Keke Marwa/Napep/Tricycle                                  No
# 4250                        NaN                                 NaN
# 4269  Keke Marwa/Napep/Tricycle                                  No
# 4275                        NaN                                 NaN
# 4282  Keke Marwa/Napep/Tricycle                                  No
# 4312        Commercial Vehicles                                  No
# 4329                        NaN                                 NaN
# 4337                 Motorcycle                                  No
# 4359                        Car             No: From my current job
# 4400                        NaN                                 NaN
# 4421                 Motorcycle                                  No
# 4469                        NaN                                 NaN
# 4497                        NaN                                 NaN
# 4517        Commercial Vehicles             No: From my current job
# 4531        Commercial Vehicles                                  No
# 4568                        NaN                                 NaN
# 4585  Keke Marwa/Napep/Tricycle                                  No
# 4589                        Car             No: From my current job
# 4610                        NaN                                 NaN
# 4634                        Car              Yes: From my first job
# 4648                        NaN                                 NaN
# 4659                        NaN                                 NaN
# 4744        Commercial Vehicles                                  No
# 4781                        NaN                                 NaN
# 4790                        NaN                                 NaN
# 4829                        NaN                                 NaN
#
#      studied_course_prepared_employment  \
# 2                              Disagree
# 3                                   NaN
# 74                       Strongly Agree
# 102                               Agree
# 111                                 NaN
# 117                               Agree
# 127                      Strongly Agree
# 128                               Agree
# 133                                 NaN
# 144                      Strongly Agree
# 149                                 NaN
# 158                   Strongly Disagree
# 226                      Strongly Agree
# 275                      Strongly Agree
# 291                                 NaN
# 339                   Strongly Disagree
# 388                                 NaN
# 511                                 NaN
# 543                                 NaN
# 648                                 NaN
# 693                      Strongly Agree
# 728                               Agree
# 808                               Agree
# 811                                 NaN
# 823                      Strongly Agree
# 834                               Agree
# 836                   Strongly Disagree
# 851                   Strongly Disagree
# 859                   Strongly Disagree
# 946                            Disagree
# ...                                 ...
# 4144                                NaN
# 4149                              Agree
# 4156                     Strongly Agree
# 4188                  Strongly Disagree
# 4243                              Agree
# 4250                                NaN
# 4269                              Agree
# 4275                                NaN
# 4282                              Agree
# 4312                           Disagree
# 4329                                NaN
# 4337                     Strongly Agree
# 4359                     Strongly Agree
# 4400                                NaN
# 4421                              Agree
# 4469                                NaN
# 4497                                NaN
# 4517                              Agree
# 4531                     Strongly Agree
# 4568                                NaN
# 4585                              Agree
# 4589                     Strongly Agree
# 4610                                NaN
# 4634                              Agree
# 4648                                NaN
# 4659                                NaN
# 4744                  Strongly Disagree
# 4781                                NaN
# 4790                                NaN
# 4829                                NaN
#
#      studied_course_prepared_further_studies  \
# 2                                      Agree
# 3                                        NaN
# 74                            Strongly Agree
# 102                                    Agree
# 111                                      NaN
# 117                                    Agree
# 127                           Strongly Agree
# 128                           Strongly Agree
# 133                                      NaN
# 144                           Strongly Agree
# 149                                      NaN
# 158                           Strongly Agree
# 226                           Strongly Agree
# 275                           Strongly Agree
# 291                                      NaN
# 339                                    Agree
# 388                                      NaN
# 511                                      NaN
# 543                                      NaN
# 648                                      NaN
# 693                           Strongly Agree
# 728                           Strongly Agree
# 808                                    Agree
# 811                                      NaN
# 823                           Strongly Agree
# 834                                    Agree
# 836                                    Agree
# 851                           Strongly Agree
# 859                        Strongly Disagree
# 946                                    Agree
# ...                                      ...
# 4144                                     NaN
# 4149                                   Agree
# 4156                                   Agree
# 4188                       Strongly Disagree
# 4243                                Disagree
# 4250                                     NaN
# 4269                          Strongly Agree
# 4275                                     NaN
# 4282                                   Agree
# 4312                                   Agree
# 4329                                     NaN
# 4337                          Strongly Agree
# 4359                          Strongly Agree
# 4400                                     NaN
# 4421                                   Agree
# 4469                                     NaN
# 4497                                     NaN
# 4517                                   Agree
# 4531                          Strongly Agree
# 4568                                     NaN
# 4585                          Strongly Agree
# 4589                          Strongly Agree
# 4610                                     NaN
# 4634                                Disagree
# 4648                                     NaN
# 4659                                     NaN
# 4744                       Strongly Disagree
# 4781                                     NaN
# 4790                                     NaN
# 4829                                     NaN
#
#                         skills_school_prepared_gradutae
# 2     Ability to work with others, Written communica...
# 3                                                   NaN
# 74    Critical thinking skills, Ability to solve com...
# 102   Critical thinking skills, Ability to solve com...
# 111                                                 NaN
# 117   Critical thinking skills, Ability to solve com...
# 127                            Critical thinking skills
# 128   Critical thinking skills, Ability to solve com...
# 133                                                 NaN
# 144   Critical thinking skills, Ability to solve com...
# 149                                                 NaN
# 158                        Written communication skills
# 226                   Ability to solve complex problems
# 275                            Critical thinking skills
# 291                                                 NaN
# 339          Knowledge of the skill(s) you are studying
# 388                                                 NaN
# 511                                                 NaN
# 543                                                 NaN
# 648                                                 NaN
# 693   Critical thinking skills, Ability to solve com...
# 728                            Critical thinking skills
# 808   Critical thinking skills, Ability to solve com...
# 811                                                 NaN
# 823   Critical thinking skills, Ability to solve com...
# 834                   Ability to solve complex problems
# 836                            Critical thinking skills
# 851                         Ability to work with others
# 859                            Critical thinking skills
# 946          Knowledge of the skill(s) you are studying
# ...                                                 ...
# 4144                                                NaN
# 4149  Critical thinking skills, Ability to solve com...
# 4156                        Spoken communication skills
# 4188         Knowledge of the skill(s) you are studying
# 4243                        Ability to work with others
# 4250                                                NaN
# 4269                        Ability to work with others
# 4275                                                NaN
# 4282  Critical thinking skills, Ability to solve com...
# 4312  Critical thinking skills, Ability to solve com...
# 4329                                                NaN
# 4337                           Critical thinking skills
# 4359  Critical thinking skills, Ability to solve com...
# 4400                                                NaN
# 4421                       Written communication skills
# 4469                                                NaN
# 4497                                                NaN
# 4517                        Ability to work with others
# 4531  Written communication skills, Spoken communica...
# 4568                                                NaN
# 4585  Critical thinking skills, Ability to solve com...
# 4589                  Ability to solve complex problems
# 4610                                                NaN
# 4634  Critical thinking skills, Ability to solve com...
# 4648                                                NaN
# 4659                                                NaN
# 4744                                  None of the above
# 4781                                                NaN
# 4790                                                NaN
# 4829                                                NaN
#
# [167 rows x 35 columns]

# %%
#We have got some values so we are gonna 'predict' the 'completed_nysc_year' based on 'graduated'
def getNyscCompletedYear(data):
    for i in data.index:
        if(np.isnan(data.at[i, 'completed_nysc_year'])) & (data.at[i, 'completed_nysc'] == 'Yes'):
            data.at[i, 'completed_nysc_year'] = data.at[i, 'graduated'] + 1
            
getNyscCompletedYear(data)

# %%
#lets confirm 
data.loc[(data['completed_nysc_year'].isnull()) & (data['completed_nysc'] == 'Yes')]
# Out:
# Empty DataFrame
# Columns: [gender, graduated, course, school, education_level, current_status, jobs_after_graduation_plus_current, completed_nysc, completed_nysc_year, first_job_through_nysc, first_job_level, first_job_role, first_job_company_sector, first_monthly_income, needed_qualification_for_first_job, first_job_reason, current_job_level, current_job_role, current_company_sector, current_monthly_income, needed_qualification_for_current_job, current_job_reason, best_company_for_graduates, why_company_best_for_graduates, best_sector_to_work, currency_paid_with, hours_worked_per_day, most_important_to_current_employer, job_source, worked_for_current_employer_during_school, transport_form_used, get_car_or_apartment_from_first_job, studied_course_prepared_employment, studied_course_prepared_further_studies, skills_school_prepared_gradutae]
# Index: []
#
# [0 rows x 35 columns]

# %%
#Ok. We are good. Let's see if we still have null values in 'completed_nysc_year'
data['completed_nysc_year'].value_counts(dropna=False)
#no more null values
# Out:
# 0.0       1800
# 2017.0    1508
# 2016.0     828
# 2015.0     548
# 2014.0     322
# 2018.0     136
# 2013.0      73
# 2019.0       3
# Name: completed_nysc_year, dtype: int64

# %%
#let's see columns with missing values still
null_columns = data.columns[data.isnull().any()]
data[null_columns].isnull().sum()
# Out:
# first_job_level                              3563
# first_job_role                               3564
# first_job_company_sector                     3563
# first_monthly_income                         3563
# needed_qualification_for_first_job           3563
# first_job_reason                             3563
# current_job_level                            1787
# current_job_role                             1787
# current_company_sector                       1787
# current_monthly_income                       1787
# needed_qualification_for_current_job         1787
# current_job_reason                           1787
# best_company_for_graduates                   2261
# why_company_best_for_graduates               2109
# best_sector_to_work                          1922
# currency_paid_with                           1787
# hours_worked_per_day                         1787
# most_important_to_current_employer           1787
# job_source                                   1787
# worked_for_current_employer_during_school    1787
# transport_form_used                          1787
# get_car_or_apartment_from_first_job          1787
# studied_course_prepared_employment           1787
# studied_course_prepared_further_studies      1787
# skills_school_prepared_gradutae              1787
# dtype: int64

# %%
#Look at the above, from 'first_job_level' to 'first_job_reason', there is an equal number of missing values
# (except 'first_job_role') across these columns. An answer(s) to question(a) might have caused this.
#Also, there is a pattern from current_job_level to current_job_reason. This same pattern exists from
#'currency_paid_with' to 'skills_school_prepared_gradutae'. I am assuming these graduates have no jobs currently
#It is also possible that some graduates have never worked so we are gonna have null values in both
#'current job' and 'first job' columns

# %%
#We are gonna assume columns related to current jobs that are null is because the graduates 
#were unemployed at that point in time. We are going to do some replacing.

def adjustCurrentStatus(data):
    for i in data.index:
        if pd.isnull(data.at[i, 'current_job_level']): #'current_job_level' works for other 'current jobs' related columns
            data.at[i, 'current_job_level'] = 'Unemployed'
            data.at[i, 'current_job_role'] = 'Unemployed'
            data.at[i, 'current_company_sector'] = 'Unemployed'
            data.at[i, 'current_monthly_income'] = 'No Income'
            data.at[i, 'needed_qualification_for_current_job'] = 'Unemployed'
            data.at[i, 'current_job_reason'] = 'Unemployed'
            data.at[i, 'best_company_for_graduates'] = 'No Opinion'
            data.at[i, 'why_company_best_for_graduates'] = 'No Opinion'
            data.at[i, 'best_sector_to_work'] = 'No Opinion'
            data.at[i, 'currency_paid_with'] = 'Unemployed'
            data.at[i, 'hours_worked_per_day'] = 0
            data.at[i, 'most_important_to_current_employer'] = 'No Opinion'
            data.at[i, 'job_source'] = 'No Opinion'
            data.at[i, 'worked_for_current_employer_during_school'] = 'No Opinion'
            data.at[i, 'transport_form_used'] = 'Unemployed'
            data.at[i, 'get_car_or_apartment_from_first_job'] = 'Unemployed'
            data.at[i, 'studied_course_prepared_employment'] = 'Unemployed'
            data.at[i, 'studied_course_prepared_further_studies'] = 'Unemployed'
            data.at[i, 'skills_school_prepared_gradutae'] = 'Unemployed'
            
adjustCurrentStatus(data)

# %%
#lets check remaining missing values
null_columns = data.columns[data.isnull().any()]
data[null_columns].isnull().sum()
# Out:
# first_job_level                       3563
# first_job_role                        3564
# first_job_company_sector              3563
# first_monthly_income                  3563
# needed_qualification_for_first_job    3563
# first_job_reason                      3563
# best_company_for_graduates             474
# why_company_best_for_graduates         322
# best_sector_to_work                    135
# dtype: int64

# %%
#More assumptions, it is possible that a graduate may have never worked so he/she might have a first job. 
#This may explain why we have similar null rows across the 'first job' column. I am gonna replace
#these null values if the 'first_job_level' is 'Unemployed' and 'jobs_after_graduation_plus_current' is 0

def adjustFirstJobs(data):
    for i in data.index:
        if (data.at[i, 'jobs_after_graduation_plus_current'] == completed_nysc0) & (pd.isnull(data.at[i, 'first_job_level'])):
            data.at[i, 'first_job_level'] = 'Unemployed'
            data.at[i, 'first_job_role'] = 'Unemployed'
            data.at[i, 'first_job_company_sector'] = 'Unemployed'
            data.at[i, 'first_monthly_income'] = 'No Income'
            data.at[i, 'needed_qualification_for_first_job'] = 'Unemployed'
            data.at[i, 'first_job_reason'] = 'No Opinion'
        
adjustFirstJobs(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-f730fa84ff6c> in <module>
#      13             data.at[i, 'first_job_reason'] = 'No Opinion'
#      14
# ---> 15 adjustFirstJobs(data)
#
# <ipython-input-34-f730fa84ff6c> in adjustFirstJobs(data)
#       5 def adjustFirstJobs(data):
#       6     for i in data.index:
# ----> 7         if (data.at[i, 'jobs_after_graduation_plus_current'] == completed_nysc0) & (pd.isnull(data.at[i, 'first_job_level'])):
#       8             data.at[i, 'first_job_level'] = 'Unemployed'
#       9             data.at[i, 'first_job_role'] = 'Unemployed'
#
# NameError: name 'completed_nysc0' is not defined

# %%
#lets check remaining missing values
null_columns = data.columns[data.isnull().any()]
data[null_columns].isnull().sum()
#we still have null values and they follow a pattern (same number of null rows) especially the 
#'first job' columns

# %%
#let's look at these columns for any patterns
data2 = data.loc[data['first_job_role'].isnull()]
data2[data2.columns[4:15]]

# %%
#for some wierd reasons, these graduates answered filled nothing for their  despite claiming to have had at least
#one job. This is erraneous and can negatively impact our analysis. I am going drop rows where graduates have had
#at least a job but didn't fill any of the 'first jobs' columns

def dropNullFirstJobColumns(data):
    for i in data.index:
        if (data.at[i, 'jobs_after_graduation_plus_current'] >= 1) & (pd.isnull(data.at[i, 'first_job_role'])):
            data.drop([i], axis=0, inplace=True)

dropNullFirstJobColumns(data)

# %%
#lets check remaining missing values
null_columns = data.columns[data.isnull().any()]
data[null_columns].isnull().sum()

# %%
#It is possible we have null values on these columns because these graduates have no answers to the questions
#we are gonna drop them. 
data.dropna(subset=['best_company_for_graduates', 'why_company_best_for_graduates', 'best_sector_to_work'], inplace=True)

# %%
#we are good now. We now have 3194 rows and 35 columns. 
data.shape

# %%
#univariate analysis for categorical data

# %%
#Current status of the graduates
yy = data.loc[data['current_status'] != 'Unemployed']['current_status'] #format series
ax = sns.countplot(y=yy, data=data)
plt.title('Current Status of Graduates')
plt.xlabel('Number of graduates')

total = len(data['current_status'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

#Majority (about 35%) of graduates are employed. Less than 29% are idle.

# %%
#school distribution. I have limited the rows to 10. 
data['school'].value_counts().nlargest(10)
#Bulk of correspondents graduated from Covenant university and the University of Lagos.

# %%
#course distribution
data['course'].value_counts().nlargest(10)
#Most correspondents studied Computer science.

# %%
fig, ax = plt.subplots(2, 2)
plt.subplots_adjust(hspace = 1)
sns.countplot(y='first_job_level', data=data, ax=ax[0, 0]).set_title('first Job level')
sns.countplot(x='first_job_through_nysc', data=data, ax=ax[0, 1]).set_title('First Job through NYSC')
sns.countplot(y='needed_qualification_for_first_job', data=data, ax=ax[1, 0]).set_title('Needed qualification for first job')
#Most graduates start out as entry level staff
#only about 20% get their first jobs via NYSC
#Companies heavily require graduates to posses some sort of qualification

# %%
data.loc[data['first_job_role'] != 'Unemployed']['first_job_role'].value_counts().nlargest(10)
#Teaching and customer service provided more jobs for fresh graduates.

# %%
yy = data.loc[data['first_monthly_income'] != 'No Income']['first_monthly_income'] #format series
ax = sns.countplot(y=yy, data=data)
plt.title('First Monthly Income for Graduates')
plt.xlabel('Number of graduates')

total = len(yy)
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
#Approximately 90% of graduates earn than 100k on their first job. Only 1.9% earn more than 200k

# %%
#Reasons for graduates' first job 
yy = data.loc[data['first_job_reason'] != 'No Opinion']['first_job_reason'] #format series
ax = sns.countplot(y=yy, data=data)
plt.title('Reasons for First Job')
plt.xlabel('Number of graduates')

total = len(yy)
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
#About 70% take their first-time jobs just to eke out a living
#Less than 1% of graduates get well-paying first-time jobs (200k and above). 
#Only 17% get their desired jobs.

# %%
#current monthly income
yy = data.loc[data['current_monthly_income'] != 'No Income']['current_monthly_income'] #format series
ax = sns.countplot(y=yy, data=data)
plt.title('Current Monthly Income')
plt.xlabel('Number of graduates')

total = len(yy)
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
#As at 2018, about 8% of graduates earn more than 200k. 70.4% earn less than 100k.

# %%
yy = data.loc[data['current_job_reason'] != 'Unemployed']['current_job_reason'] #format series
yy.value_counts(normalize=True).nlargest(10) * 100
#As at 2018, Only 28% get the job they wanted. Around 45% take up their current jobs to eke out a living.

# %%
yy = data.loc[data['needed_qualification_for_current_job'] != 'Unemployed']['needed_qualification_for_current_job'] #format series
sns.countplot(y = yy, data=data)
#As at 2018, qualifications were a major requirement for employment.

# %%
# best_company_for_graduates
yy = data.loc[data['best_company_for_graduates'] != 'No Opinion']['best_company_for_graduates'] #format series
yy.value_counts(normalize=True).nlargest(10)*100
#The top 5 companies to work for - Andela, KPMG, Shell, Google and Chevron.

# %%
yy = data.loc[data['why_company_best_for_graduates'] != 'No Opinion']['why_company_best_for_graduates'] #format series
yy.value_counts().nlargest(5)
#Graduates choose their 'best companies to work for' based on reviews in previous/current contact with the company

# %%
yy = data.loc[data['best_sector_to_work'] != 'No Opinion']['best_sector_to_work'] #format series
yy.value_counts().nlargest(5)
#Oil/Gas and Technology sectors are the best sectors to work for.

# %%
yy = data.loc[data['hours_worked_per_day'] != 0]['hours_worked_per_day'] #format series
sns.countplot(yy, data=data)
#Most graduates work between 8 - 10hrs/day

# %%
yy = data.loc[data['most_important_to_current_employer'] != 'No Opinion']['most_important_to_current_employer'] #format series
yy.value_counts(normalize=True).nlargest(10)*100
#educational qualifications is very important for employers. Less than 1% of employers see experience
#as an important qualification

# %%
yy = data.loc[data['job_source'] != 'No Opinion']['job_source'] #format series
yy.value_counts(normalize=True)*100
#61% of jobs are gotten via networking.

# %%
y1 = data.loc[data['studied_course_prepared_employment'] != 'Unemployed']['studied_course_prepared_employment'] #format series
y2 = data.loc[data['studied_course_prepared_further_studies'] != 'Unemployed']['studied_course_prepared_further_studies'] #format series
fig, ax = plt.subplots(1, 2)
plt.subplots_adjust(hspace = 1, left=2, right=5)
sns.countplot(y=y1, data=data, ax=ax[0]).set_title('Studied course vs employment')
sns.countplot(y=y2, data=data, ax=ax[1]).set_title('Studied course vs further studies')
#less than 35% believed that their course of study had no impact in their choice of jobs
#Course of study was only important for further studies

# %%
yy = data.loc[data['skills_school_prepared_gradutae'] != 'Unemployed']['skills_school_prepared_gradutae'] #format series
yy.value_counts(normalize=True).nlargest(5)*100
#7% believed school never equipped them with any skills
#18% of graduates were equipped with essential skills needed to survive outside the 4 walls of school.

# %%
#multi-variate analysis

# %%
#Income distribution across gender
y1 = data.loc[data['current_monthly_income'] != 'No Income']['current_monthly_income'] #format series
x1 = data.loc[data['current_monthly_income'] != 'No Income']['gender'] #format series
y2 = data.loc[data['first_monthly_income'] != 'No Income']['first_monthly_income'] #format series
x2 = data.loc[data['first_monthly_income'] != 'No Income']['gender'] #format series
fig, ax = plt.subplots(1, 2, figsize=(10, 7))
sns.countplot(x=x1, hue=y1, data=data, ax=ax[0]).set_title('Current Income distribution across Gender')
sns.countplot(x=x2, hue=y2, data=data, ax=ax[1]).set_title('First Income distribution across Gender')

#Men are generally paid more than women.

# %%
#Analysing graduates with high paying jobs (>=200k)
array = ['‎₦250,000 and more', '‎₦200,000 - ‎₦249,999']
new_df = data.loc[data['current_monthly_income'].isin(array)]
new_df = new_df[['current_monthly_income', 'school', 'current_company_sector', 'job_source']]
new_df['school'].value_counts().nlargest(3)
#High paying jobs (=>200k) are gotten by covenant university and university of lagos graduates

# %%
#So why do students of covenant and university of lagos get high paying jobs?
schools = ['Covenant University Ota', 'University of Lagos']
new_df2 = new_df[data['school'].isin(schools)]
new_df2['job_source'].value_counts()

ax = sns.countplot(y="job_source", data=new_df2)
plt.title('Source of High Paying Jobs')
plt.xlabel('Number of graduates')

total = len(new_df2['job_source'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
        
#Personal contacts are important in getting high-paying jobs
